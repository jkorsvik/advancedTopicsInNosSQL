# %%
# Standard libraries
import pandas as pd
import json
import numpy as np
import pandas as pd
from scipy import stats
from copy import copy
import pyprind
from itertools import product
from time import sleep
from tqdm import tqdm

# Plots and visualizations
import matplotlib.pyplot as plt
import seaborn as sns

df_raw = pd.read_json("stocks.json", lines=True)
df_raw.head(2)
# Out:
#                                     _id                    Company  Price  \
# 0  {'$oid': '52853800bb1177ca391c17ff'}  Agilent Technologies Inc.  50.44
# 1  {'$oid': '52853800bb1177ca391c1800'}                Alcoa, Inc.   9.02
#
#                                Earnings Date  \
# 0  {'$date': '2013-11-14T21:30:00.000+0000'}
# 1  {'$date': '2013-10-08T20:30:00.000+0000'}
#
#                                          description  \
# 0  {'Country': 'USA', 'Sector': 'Healthcare', 'In...
# 1  {'Country': 'USA', 'Sector': 'Basic Materials'...
#
#    20-Day Simple Moving Average  200-Day Simple Moving Average  \
# 0                       -0.0172                         0.1062
# 1                       -0.0192                         0.0823
#
#                             50-Day                          52-Week  \
# 0  [0.0728, -0.054400000000000004]  [0.4378, -0.054400000000000004]
# 1                [0.1579, -0.0925]                [0.1899, -0.0925]
#
#    Analyst Recom  Average True Range  Average Volume  Beta  Change  EPS ttm  \
# 0            1.6                0.86         2569.36  1.50 -0.0148     2.68
# 1            3.1                0.30        26728.11  2.02  0.0033     0.25
#
#      ROI                                          ratio  \
# 0  0.163                   {'quick': 2.3, 'current': 3}
# 1  0.007  {'quick': 0.7000000000000001, 'current': 1.2}
#
#                                          performance
# 0  {'Year': 0.4242, 'Half Year': 0.1439, 'Month':...
# 1  {'Year': 0.09630000000000001, 'Half Year': 0.0...

# %%
# Utility function

def resumetable(df):
    print(f"Dataset Shape: {df.shape}")
    summary = pd.DataFrame(df.dtypes,columns=['dtypes'])
    summary = summary.reset_index()
    summary['Name'] = summary['index']
    summary = summary[['Name','dtypes']]
    summary['Missing'] = df.isnull().sum().values    
    #summary['Uniques'] = df.nunique().values
    summary['First Value'] = df.loc[0].values
    summary['Second Value'] = df.loc[1].values
    summary['Third Value'] = df.loc[2].values

    return summary

resumetable(df_raw)
# Out:
# Dataset Shape: (6756, 18)
#                              Name   dtypes  Missing  \
# 0                             _id   object        0
# 1                         Company   object        0
# 2                           Price  float64       13
# 3                   Earnings Date   object     2198
# 4                     description   object        0
# 5    20-Day Simple Moving Average  float64       14
# 6   200-Day Simple Moving Average  float64       14
# 7                          50-Day   object        0
# 8                         52-Week   object        0
# 9                   Analyst Recom  float64     2591
# 10             Average True Range  float64       14
# 11                 Average Volume  float64       14
# 12                           Beta  float64     2547
# 13                         Change  float64       14
# 14                        EPS ttm  float64     1728
# 15                            ROI  float64     2104
# 16                          ratio   object        0
# 17                    performance   object        0
#
#                                           First Value  \
# 0                {'$oid': '52853800bb1177ca391c17ff'}
# 1                           Agilent Technologies Inc.
# 2                                               50.44
# 3           {'$date': '2013-11-14T21:30:00.000+0000'}
# 4   {'Country': 'USA', 'Sector': 'Healthcare', 'In...
# 5                                             -0.0172
# 6                                              0.1062
# 7                     [0.0728, -0.054400000000000004]
# 8                     [0.4378, -0.054400000000000004]
# 9                                                 1.6
# 10                                               0.86
# 11                                            2569.36
# 12                                                1.5
# 13                                            -0.0148
# 14                                               2.68
# 15                                              0.163
# 16                       {'quick': 2.3, 'current': 3}
# 17  {'Year': 0.4242, 'Half Year': 0.1439, 'Month':...
#
#                                          Second Value  \
# 0                {'$oid': '52853800bb1177ca391c1800'}
# 1                                         Alcoa, Inc.
# 2                                                9.02
# 3           {'$date': '2013-10-08T20:30:00.000+0000'}
# 4   {'Country': 'USA', 'Sector': 'Basic Materials'...
# 5                                             -0.0192
# 6                                              0.0823
# 7                                   [0.1579, -0.0925]
# 8                                   [0.1899, -0.0925]
# 9                                                 3.1
# 10                                                0.3
# 11                                           26728.11
# 12                                               2.02
# 13                                             0.0033
# 14                                               0.25
# 15                                              0.007
# 16      {'quick': 0.7000000000000001, 'current': 1.2}
# 17  {'Year': 0.09630000000000001, 'Half Year': 0.0...
#
#                                           Third Value
# 0                {'$oid': '52853800bb1177ca391c1801'}
# 1               WCM/BNY Mellon Focused Growth ADR ETF
# 2                                                36.4
# 3                                                None
# 4   {'Country': 'USA', 'Sector': 'Financial', 'Ind...
# 5                                             -0.0054
# 6                                              0.0693
# 7                                   [0.0792, -0.0194]
# 8                                   [0.2727, -0.0194]
# 9                                                 NaN
# 10                                               0.31
# 11                                              10.07
# 12                                                NaN
# 13                                             0.0064
# 14                                                NaN
# 15                                                NaN
# 16                   {'quick': None, 'current': None}
# 17  {'Year': 0.229, 'Half Year': 0.04, 'Month': 0....

# %%
for col in df_raw:
    print(col)
    print(type(df_raw[col].values[0]))
    print("---------------")
# Out:
# _id
# <class 'dict'>
# ---------------
# Company
# <class 'str'>
# ---------------
# Price
# <class 'numpy.float64'>
# ---------------
# Earnings Date
# <class 'dict'>
# ---------------
# description
# <class 'dict'>
# ---------------
# 20-Day Simple Moving Average
# <class 'numpy.float64'>
# ---------------
# 200-Day Simple Moving Average
# <class 'numpy.float64'>
# ---------------
# 50-Day
# <class 'list'>
# ---------------
# 52-Week
# <class 'list'>
# ---------------
# Analyst Recom
# <class 'numpy.float64'>
# ---------------
# Average True Range
# <class 'numpy.float64'>
# ---------------
# Average Volume
# <class 'numpy.float64'>
# ---------------
# Beta
# <class 'numpy.float64'>
# ---------------
# Change
# <class 'numpy.float64'>
# ---------------
# EPS ttm
# <class 'numpy.float64'>
# ---------------
# ROI
# <class 'numpy.float64'>
# ---------------
# ratio
# <class 'dict'>
# ---------------
# performance
# <class 'dict'>
# ---------------

# %%
_id_column = df_raw["_id"].apply(lambda x: x.get('$oid'))
# np.datetime64
_id_column
# Out:
# 0       52853800bb1177ca391c17ff
# 1       52853800bb1177ca391c1800
# 2       52853800bb1177ca391c1801
# 3       52853800bb1177ca391c1802
# 4       52853800bb1177ca391c1803
#                   ...
# 6751    52853810bb1177ca391c325e
# 6752    52853810bb1177ca391c325f
# 6753    52853810bb1177ca391c3260
# 6754    52853810bb1177ca391c3261
# 6755    52853810bb1177ca391c3262
# Name: _id, Length: 6756, dtype: object

# %%
date_column = df_raw["Earnings Date"].apply(lambda x: np.nan if x is None else x.get('$date'))
date_column = pd.to_datetime(date_column)
date_column
# Out:
# 0      2013-11-14 21:30:00+00:00
# 1      2013-10-08 20:30:00+00:00
# 2                            NaT
# 3                            NaT
# 4                            NaT
#                   ...
# 6751                         NaT
# 6752                         NaT
# 6753   2013-11-05 13:30:00+00:00
# 6754   2013-12-05 21:30:00+00:00
# 6755   2013-11-20 13:30:00+00:00
# Name: Earnings Date, Length: 6756, dtype: datetime64[ns, UTC]

# %%
desc_column = df_raw["description"].apply(
    lambda x: x if not None else {"Country": None, "Sector": None, "Industry": None})
desc_column = desc_column.fillna("null")
desc_column
# Out:
# 0       {'Country': 'USA', 'Sector': 'Healthcare', 'In...
# 1       {'Country': 'USA', 'Sector': 'Basic Materials'...
# 2       {'Country': 'USA', 'Sector': 'Financial', 'Ind...
# 3       {'Country': 'USA', 'Sector': 'Financial', 'Ind...
# 4       {'Country': 'USA', 'Sector': 'Financial', 'Ind...
#                               ...
# 6751    {'Country': 'USA', 'Sector': 'Financial', 'Ind...
# 6752    {'Country': 'USA', 'Sector': 'Financial', 'Ind...
# 6753    {'Country': 'USA', 'Sector': 'Healthcare', 'In...
# 6754    {'Country': 'USA', 'Sector': 'Services', 'Indu...
# 6755    {'Country': 'China', 'Sector': 'Consumer Goods...
# Name: description, Length: 6756, dtype: object

# %%
# Make description node based on the combinations of
# descriptions

country = desc_column.apply(lambda x: x["Country"]).unique()
sector = desc_column.apply(lambda x: x["Sector"]).unique()
industry = desc_column.apply(lambda x: x["Industry"]).unique()

#desc_combs = 
combinations = np.array(list(product(country, sector, industry)))
desc_nodes = pd.DataFrame(combinations, columns=[
    "Country", "Sector", "Industry"
])
desc_nodes

# Not plausable due to time complexy and overhead
"""for ind, data in desc_column.iteritems():
    for ind_match, data_match in desc_nodes.iterrows():
        if data["Country"] == data_match["Country"] \
            and data["Sector"] == data_match["Sector"] \
            and data["Industry"] == data_match["Industry"]:
            desc_ids.append(ind_match)"""
# Out:
# 'for ind, data in desc_column.iteritems():\n    for ind_match, data_match in desc_nodes.iterrows():\n        if data["Country"] == data_match["Country"]             and data["Sector"] == data_match["Sector"]             and data["Industry"] == data_match["Industry"]:\n            desc_ids.append(ind_match)'

# %%
desc_ids = []
for ind, data in tqdm(desc_column.iteritems()):
    desc_ids.append(
        desc_nodes[(desc_nodes["Country"] == data["Country"])
                &  (desc_nodes["Sector"] == data["Sector"])
                &  (desc_nodes["Industry"]== data["Industry"])].index)
# Out:
# 6756it [03:54, 28.81it/s]

# %%
desc_ids = np.array(desc_ids)
desc_ids
# Out:
# array([[    0],
#        [  217],
#        [  434],
#        ...,
#        [   46],
#        [  797],
#        [11123]], dtype=int64)

# %%
perf_column = df_raw["performance"].apply(
    lambda x: x if not None else {"Year": None, "Half Year": None, "Month": None, "Week": None})
perf_column = perf_column.apply(lambda x: {"HalfYear" if k == "Half Year"  else k:v for k,v in x.items()}
                                   )
perf_column[0]
# Out:
# {'Year': 0.4242,
#  'HalfYear': 0.1439,
#  'Month': 0.0063,
#  'Week': 0.0031000000000000003}

# %%
ratio_column = df_raw["ratio"].apply(lambda x: x if not None else {"quick": None, "current": None})
ratio_column = ratio_column.fillna("null")

# %%
df_raw
# Out:
#                                        _id  \
# 0     {'$oid': '52853800bb1177ca391c17ff'}
# 1     {'$oid': '52853800bb1177ca391c1800'}
# 2     {'$oid': '52853800bb1177ca391c1801'}
# 3     {'$oid': '52853800bb1177ca391c1802'}
# 4     {'$oid': '52853800bb1177ca391c1803'}
# ...                                    ...
# 6751  {'$oid': '52853810bb1177ca391c325e'}
# 6752  {'$oid': '52853810bb1177ca391c325f'}
# 6753  {'$oid': '52853810bb1177ca391c3260'}
# 6754  {'$oid': '52853810bb1177ca391c3261'}
# 6755  {'$oid': '52853810bb1177ca391c3262'}
#
#                                       Company   Price  \
# 0                   Agilent Technologies Inc.   50.44
# 1                                 Alcoa, Inc.    9.02
# 2       WCM/BNY Mellon Focused Growth ADR ETF   36.40
# 3       iShares MSCI AC Asia Information Tech   29.95
# 4     Altisource Asset Management Corporation  597.98
# ...                                       ...     ...
# 6751              ProShares UltraShort Silver   80.70
# 6752             Zweig Total Return Fund Inc.   13.53
# 6753                              Zoetis Inc.   31.65
# 6754                             Zumiez, Inc.   29.56
# 6755      China Zenix Auto International Ltd.    3.83
#
#                                   Earnings Date  \
# 0     {'$date': '2013-11-14T21:30:00.000+0000'}
# 1     {'$date': '2013-10-08T20:30:00.000+0000'}
# 2                                          None
# 3                                          None
# 4                                          None
# ...                                         ...
# 6751                                       None
# 6752                                       None
# 6753  {'$date': '2013-11-05T13:30:00.000+0000'}
# 6754  {'$date': '2013-12-05T21:30:00.000+0000'}
# 6755  {'$date': '2013-11-20T13:30:00.000+0000'}
#
#                                             description  \
# 0     {'Country': 'USA', 'Sector': 'Healthcare', 'In...
# 1     {'Country': 'USA', 'Sector': 'Basic Materials'...
# 2     {'Country': 'USA', 'Sector': 'Financial', 'Ind...
# 3     {'Country': 'USA', 'Sector': 'Financial', 'Ind...
# 4     {'Country': 'USA', 'Sector': 'Financial', 'Ind...
# ...                                                 ...
# 6751  {'Country': 'USA', 'Sector': 'Financial', 'Ind...
# 6752  {'Country': 'USA', 'Sector': 'Financial', 'Ind...
# 6753  {'Country': 'USA', 'Sector': 'Healthcare', 'In...
# 6754  {'Country': 'USA', 'Sector': 'Services', 'Indu...
# 6755  {'Country': 'China', 'Sector': 'Consumer Goods...
#
#       20-Day Simple Moving Average  200-Day Simple Moving Average  \
# 0                          -0.0172                         0.1062
# 1                          -0.0192                         0.0823
# 2                          -0.0054                         0.0693
# 3                          -0.0295                         0.0492
# 4                          -0.0189                         0.9846
# ...                            ...                            ...
# 6751                        0.1056                         0.0874
# 6752                        0.0128                         0.0714
# 6753                       -0.0127                        -0.0043
# 6754                        0.0083                         0.0773
# 6755                        0.0000                         0.2125
#
#                                50-Day  \
# 0     [0.0728, -0.054400000000000004]
# 1                   [0.1579, -0.0925]
# 2                   [0.0792, -0.0194]
# 3                   [0.0609, -0.0641]
# 4       [0.8672000000000001, -0.1812]
# ...                               ...
# 6751                 [0.3103, -0.039]
# 6752                      [0.0771, 0]
# 6753                [0.0692, -0.0487]
# 6754  [0.2353, -0.023100000000000002]
# 6755   [0.3345, -0.10300000000000001]
#
#                                          52-Week  Analyst Recom  \
# 0                [0.4378, -0.054400000000000004]            1.6
# 1                              [0.1899, -0.0925]            3.1
# 2                              [0.2727, -0.0194]            NaN
# 3                              [0.1791, -0.0641]            NaN
# 4                             [38.8653, -0.1812]            NaN
# ...                                          ...            ...
# 6751                           [1.0457, -0.3058]            NaN
# 6752                    [0.23190000000000002, 0]            NaN
# 6753                            [0.1008, -0.101]            1.7
# 6754  [0.6486000000000001, -0.11760000000000001]            2.6
# 6755  [0.5892000000000001, -0.10300000000000001]            2.0
#
#       Average True Range  Average Volume  Beta  Change  EPS ttm    ROI  \
# 0                   0.86         2569.36  1.50 -0.0148     2.68  0.163
# 1                   0.30        26728.11  2.02  0.0033     0.25  0.007
# 2                   0.31           10.07   NaN  0.0064      NaN    NaN
# 3                   0.45            1.64   NaN -0.0200      NaN    NaN
# 4                  30.17            4.94   NaN  0.0135    -0.02    NaN
# ...                  ...             ...   ...     ...      ...    ...
# 6751                2.50          397.30   NaN -0.0213      NaN    NaN
# 6752                0.10           91.86   NaN  0.0059      NaN    NaN
# 6753                0.62         4032.97   NaN -0.0022     0.84  0.095
# 6754                0.89          225.29  1.62 -0.0003     1.39  0.131
# 6755                0.20           22.69   NaN  0.0026     0.70  0.121
#
#                                               ratio  \
# 0                      {'quick': 2.3, 'current': 3}
# 1     {'quick': 0.7000000000000001, 'current': 1.2}
# 2                  {'quick': None, 'current': None}
# 3                  {'quick': None, 'current': None}
# 4                  {'quick': None, 'current': None}
# ...                                             ...
# 6751               {'quick': None, 'current': None}
# 6752               {'quick': None, 'current': None}
# 6753                 {'quick': 1.4, 'current': 2.3}
# 6754                 {'quick': 1.4, 'current': 2.7}
# 6755                 {'quick': 1.1, 'current': 1.3}
#
#                                             performance
# 0     {'Year': 0.4242, 'Half Year': 0.1439, 'Month':...
# 1     {'Year': 0.09630000000000001, 'Half Year': 0.0...
# 2     {'Year': 0.229, 'Half Year': 0.04, 'Month': 0....
# 3     {'Year': 0.1947, 'Half Year': 0.0307, 'Month':...
# 4     {'Year': None, 'Half Year': 0.9832000000000001...
# ...                                                 ...
# 6751  {'Year': 0.8501000000000001, 'Half Year': 0.04...
# 6752  {'Year': 0.185, 'Half Year': 0.0443, 'Month': ...
# 6753  {'Year': None, 'Half Year': -0.046, 'Month': -...
# 6754  {'Year': 0.44670000000000004, 'Half Year': -0....
# 6755  {'Year': 0.3357, 'Half Year': 0.3038, 'Month':...
#
# [6756 rows x 18 columns]

# %%
df_clean = df_raw
df_clean["_id"] = _id_column
df_clean["Earnings Date"] = date_column
df_clean["description"] = desc_ids
df_clean["performance"] = perf_column
df_clean["ratio"] = ratio_column
df_clean.columns = ["id", "company", "price", "earningsdate", 
"desc_id", "SMA20", "SMA200", "days50highlow", 
"weeks52highlow", "analyst_recommendation", 
"avg_true_rate", "avg_vol", "beta", "change", 
"EPSttm", "ROI", "ratio", "performance"]

df_clean.head(2)
# Out:
#                          id                    company  price  \
# 0  52853800bb1177ca391c17ff  Agilent Technologies Inc.  50.44
# 1  52853800bb1177ca391c1800                Alcoa, Inc.   9.02
#
#                earningsdate  desc_id   SMA20  SMA200  \
# 0 2013-11-14 21:30:00+00:00        0 -0.0172  0.1062
# 1 2013-10-08 20:30:00+00:00      217 -0.0192  0.0823
#
#                      days50highlow                   weeks52highlow  \
# 0  [0.0728, -0.054400000000000004]  [0.4378, -0.054400000000000004]
# 1                [0.1579, -0.0925]                [0.1899, -0.0925]
#
#    analyst_recommendation  avg_true_rate   avg_vol  beta  change  EPSttm  \
# 0                     1.6           0.86   2569.36  1.50 -0.0148    2.68
# 1                     3.1           0.30  26728.11  2.02  0.0033    0.25
#
#      ROI                                          ratio  \
# 0  0.163                   {'quick': 2.3, 'current': 3}
# 1  0.007  {'quick': 0.7000000000000001, 'current': 1.2}
#
#                                          performance
# 0  {'Year': 0.4242, 'HalfYear': 0.1439, 'Month': ...
# 1  {'Year': 0.09630000000000001, 'HalfYear': 0.06...

# %%
desc_nodes.index.name = "desc_id"

# %%
desc_nodes.to_csv("desc_nodes.csv")

# %%
df_clean.to_csv("stocks_clean.csv", index=False)

# %%
df_clean.to_json("stocks_clean.json", orient='records')

# %%
import json
import re
 
# Opening JSON file
f = open('stocks_clean.json')
 
# returns JSON object as
# a dictionary
data = json.load(f)
 
ratio_ = ["current", "quick"]
perf_ = ["Year", "Half_Year", "Month", "Week"]
desc_ = ["Country", "Sector", "Industry"]
 
# Iterating through the json
# list
# BIG O = O(n*m), n is rows and m is number of key-value pairs
with open('insert_json.cql', 'w') as f:
    for row in data:
        string = str(row).replace("'", '"')
        string = string.replace("Half Year", "Half_Year")
        string = string.replace("None", 'null')
        # Regex find empty values in dictonary
        
        # Replacing empty values with null
        pattern = r'"(\w+)": null'
        null_value_kwgargs = re.findall(pattern, string)
        for match in null_value_kwgargs:
            if match in ratio_:
                string = string.replace(f'"{match}": null', f'"{match}": 0.0')
            elif match in perf_:
                string = string.replace(f'"{match}": null', f'"{match}": 0.0')
            elif match in desc_:
                string = string.replace(f'"{match}": null', f'"{match}": ""')
            elif match == "price":
                string = string.replace(f'"{match}": null', f'"{match}": 0.0')
            else:
                continue
        
        """if len(null_value_kwgargs) > 0:
            print(null_value_kwgargs)
            print(string)
            break"""
        
        f.write(f"INSERT INTO stocks.stocks JSON '{string}';\n")
# Closing file
f.close()
